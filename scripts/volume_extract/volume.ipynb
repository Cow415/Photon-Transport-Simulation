# %% [markdown]
# % Given tiff address, give volume out.

# %%
% Import libraries:
import numpy as np
import pillow as pi 
import Tiffile as tf

# %% [markdown]
# Input data path, process after; the path variable can be changed to outpt different data's geometry array.

# %%
file_name = "test.tiff"

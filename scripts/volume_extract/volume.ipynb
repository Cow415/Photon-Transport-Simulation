# %% [markdown]
# # Given tiff address in share directory, generate geometry out.
# Split into binary geometry marix and RI matrix

# %%
# Import libraries:
import numpy as np
import PIL as pi 
import tiffile as tf

# %% [markdown]
# ## Set-up I/O Path Allocations
# Declare input data path and access tiff.
# Process the RI after the set up;
# The path variable can be changed to output different data's geometry arrays.

# %%
# Declarables: 
saving_subfolder_address = "./processed_data/volume/"       
file_name = "test.tiff"                                 
raw_tiff = tf.__all__(file_name)
outpit_file_name = output_address(file_name)

save_volume_as_tiff(raw_tiff, outpit_file_name)

# Helpers:
def output_address(file_name):

    return 

def save_volume_as_tiff(volume, output_file_name):

    tf.imsave(output_file_name, volume)
    return print("Volume saved as tiff file as: ", output_file_name)

# %% [markdown]
# ## Define Important Parameters
# Declare Threshold Value for solid existance
# Declare Sizings for the solid model

# %%
# Initialization: 
image = pi.Image.open(file_name)
image_array = np.array(image)

# Apply RI Threshold to mask the image:
ri_threshold = 1.33     # Can be changed
mask = image_array > ri_threshold

# Save the masked image:

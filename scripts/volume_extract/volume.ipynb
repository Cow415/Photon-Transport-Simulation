# %% [markdown]
# # Given tiff address in share directory, generate geometry out.
# Split into binary geometry marix and RI matrix

# %%
# Import libraries:
import numpy as np
import PIL as pi 
import tiffile as tf

# %% [markdown]
# Input data path and access tiff. Process after; the path variable can be changed to output different data's geometry arrays.

# %%
file_name = "test.tiff"
raw_tiff = tf.__all__(file_name)
